# %%
# !pip install transformers datasets torch scikit-learn

# %%
# !pip install tf-keras

# %%
# !jupyter nbextension enable --py widgetsnbextension

# %%
# Out:
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 22
#      19     return tokenizer(examples["text"], padding="max_length", truncation=True)
#      21 # Apply tokenization to the dataset
# ---> 22 tokenized_datasets = dataset.map(tokenize_function, batched=True)
#      24 # Remove the original text column and rename "label" to "labels" (required by Trainer)
#      25 tokenized_datasets = tokenized_datasets.remove_columns(["text"])
#
# File /opt/anaconda3/lib/python3.12/site-packages/datasets/dataset_dict.py:902, in DatasetDict.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_names, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, desc)
#     898 if cache_file_names is None:
#     899     cache_file_names = {k: None for k in self}
#     900 return DatasetDict(
#     901     {
# --> 902         k: dataset.map(
#     903             function=function,
#     904             with_indices=with_indices,
#     905             with_rank=with_rank,
#     906             input_columns=input_columns,
#     907             batched=batched,
#     908             batch_size=batch_size,
#     909             drop_last_batch=drop_last_batch,
#     910             remove_columns=remove_columns,
#     911             keep_in_memory=keep_in_memory,
#     912             load_from_cache_file=load_from_cache_file,
#     913             cache_file_name=cache_file_names[k],
#     914             writer_batch_size=writer_batch_size,
#     915             features=features,
#     916             disable_nullable=disable_nullable,
#     917             fn_kwargs=fn_kwargs,
#     918             num_proc=num_proc,
#     919             desc=desc,
#     920         )
#     921         for k, dataset in self.items()
#     922     }
#     923 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py:562, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     555 self_format = {
#     556     "type": self._format_type,
#     557     "format_kwargs": self._format_kwargs,
#     558     "columns": self._format_columns,
#     559     "output_all_columns": self._output_all_columns,
#     560 }
#     561 # apply actual function
# --> 562 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     563 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     564 # re-apply format to the output
#
# File /opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py:3079, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    3073 if transformed_dataset is None:
#    3074     with hf_tqdm(
#    3075         unit=" examples",
#    3076         total=pbar_total,
#    3077         desc=desc or "Map",
#    3078     ) as pbar:
# -> 3079         for rank, done, content in Dataset._map_single(**dataset_kwargs):
#    3080             if done:
#    3081                 shards_done += 1
#
# File /opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py:3519, in Dataset._map_single(shard, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset)
#    3517 else:
#    3518     _time = time.time()
# -> 3519     for i, batch in iter_outputs(shard_iterable):
#    3520         num_examples_in_batch = len(i)
#    3521         if update_data:
#
# File /opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py:3469, in Dataset._map_single.<locals>.iter_outputs(shard_iterable)
#    3467 else:
#    3468     for i, example in shard_iterable:
# -> 3469         yield i, apply_function(example, i, offset=offset)
#
# File /opt/anaconda3/lib/python3.12/site-packages/datasets/arrow_dataset.py:3392, in Dataset._map_single.<locals>.apply_function(pa_inputs, indices, offset)
#    3390 """Utility to apply the function on a selection of columns."""
#    3391 inputs, fn_args, additional_args, fn_kwargs = prepare_inputs(pa_inputs, indices, offset=offset)
# -> 3392 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3393 return prepare_outputs(pa_inputs, inputs, processed_inputs)
#
# Cell In[4], line 19, in tokenize_function(examples)
#      18 def tokenize_function(examples):
# ---> 19     return tokenizer(examples["text"], padding="max_length", truncation=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2877, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2875     if not self._in_target_context_manager:
#    2876         self._switch_to_input_mode()
# -> 2877     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2878 if text_target is not None:
#    2879     self._switch_to_target_mode()
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:2965, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2960         raise ValueError(
#    2961             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2962             f" {len(text_pair)}."
#    2963         )
#    2964     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2965     return self.batch_encode_plus(
#    2966         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2967         add_special_tokens=add_special_tokens,
#    2968         padding=padding,
#    2969         truncation=truncation,
#    2970         max_length=max_length,
#    2971         stride=stride,
#    2972         is_split_into_words=is_split_into_words,
#    2973         pad_to_multiple_of=pad_to_multiple_of,
#    2974         padding_side=padding_side,
#    2975         return_tensors=return_tensors,
#    2976         return_token_type_ids=return_token_type_ids,
#    2977         return_attention_mask=return_attention_mask,
#    2978         return_overflowing_tokens=return_overflowing_tokens,
#    2979         return_special_tokens_mask=return_special_tokens_mask,
#    2980         return_offsets_mapping=return_offsets_mapping,
#    2981         return_length=return_length,
#    2982         verbose=verbose,
#    2983         split_special_tokens=split_special_tokens,
#    2984         **kwargs,
#    2985     )
#    2986 else:
#    2987     return self.encode_plus(
#    2988         text=text,
#    2989         text_pair=text_pair,
#    (...)
#    3007         **kwargs,
#    3008     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:3167, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3157 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3158 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3159     padding=padding,
#    3160     truncation=truncation,
#    (...)
#    3164     **kwargs,
#    3165 )
# -> 3167 return self._batch_encode_plus(
#    3168     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3169     add_special_tokens=add_special_tokens,
#    3170     padding_strategy=padding_strategy,
#    3171     truncation_strategy=truncation_strategy,
#    3172     max_length=max_length,
#    3173     stride=stride,
#    3174     is_split_into_words=is_split_into_words,
#    3175     pad_to_multiple_of=pad_to_multiple_of,
#    3176     padding_side=padding_side,
#    3177     return_tensors=return_tensors,
#    3178     return_token_type_ids=return_token_type_ids,
#    3179     return_attention_mask=return_attention_mask,
#    3180     return_overflowing_tokens=return_overflowing_tokens,
#    3181     return_special_tokens_mask=return_special_tokens_mask,
#    3182     return_offsets_mapping=return_offsets_mapping,
#    3183     return_length=return_length,
#    3184     verbose=verbose,
#    3185     split_special_tokens=split_special_tokens,
#    3186     **kwargs,
#    3187 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils.py:888, in PreTrainedTokenizer._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     885 else:
#     886     ids, pair_ids = ids_or_pair_ids
# --> 888 first_ids = get_input_ids(ids)
#     889 second_ids = get_input_ids(pair_ids) if pair_ids is not None else None
#     890 input_ids.append((first_ids, second_ids))
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils.py:855, in PreTrainedTokenizer._batch_encode_plus.<locals>.get_input_ids(text)
#     853 def get_input_ids(text):
#     854     if isinstance(text, str):
# --> 855         tokens = self.tokenize(text, **kwargs)
#     856         return self.convert_tokens_to_ids(tokens)
#     857     elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/tokenization_utils.py:698, in PreTrainedTokenizer.tokenize(self, text, **kwargs)
#     696         tokenized_text.append(token)
#     697     else:
# --> 698         tokenized_text.extend(self._tokenize(token))
#     699 # ["This", " is", " something", "<special_token_1>", "else"]
#     700 return tokenized_text
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/tokenization_bert.py:161, in BertTokenizer._tokenize(self, text, split_special_tokens)
#     159 split_tokens = []
#     160 if self.do_basic_tokenize:
# --> 161     for token in self.basic_tokenizer.tokenize(
#     162         text, never_split=self.all_special_tokens if not split_special_tokens else None
#     163     ):
#     164         # If the token is part of the never_split set
#     165         if token in self.basic_tokenizer.never_split:
#     166             split_tokens.append(token)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/tokenization_bert.py:358, in BasicTokenizer.tokenize(self, text, never_split)
#     356     token = token.lower()
#     357     if self.strip_accents is not False:
# --> 358         token = self._run_strip_accents(token)
#     359 elif self.strip_accents:
#     360     token = self._run_strip_accents(token)
#
# File /opt/anaconda3/lib/python3.12/site-packages/transformers/models/bert/tokenization_bert.py:366, in BasicTokenizer._run_strip_accents(self, text)
#     363     output_tokens = whitespace_tokenize(" ".join(split_tokens))
#     364     return output_tokens
# --> 366 def _run_strip_accents(self, text):
#     367     """Strips accents from a piece of text."""
#     368     text = unicodedata.normalize("NFD", text)
#
# KeyboardInterrupt:
